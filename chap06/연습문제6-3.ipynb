# %% [markdown]
# Moneybox 클래스를작성하라. 이클래스는저축한총액을저장하는인스턴스변수가있다.  deposit(money) 메서드는 인수로 주어진금액만큼저축하고총액을출력한다,
# extract(money) 메소드는 money를 인출하고 총액을 출력한다. get_total() 메소드는 총액을 알려준다.

# %%
class Moneybox:
    def __init__(self):
        self.total = 0 

    def deposit(self, money):
        if money > 0:
            self.total += money
            print(f"{money}원을 입금했습니다. 총액: {self.total}원")
        else:
            print("0원 이하의 금액은 입금할 수 없습니다.")

    def extract(self, money):
        if money > 0 and money <= self.total:
            self.total -= money
            print(f"{money}원을 인출했습니다. 총액: {self.total}원")
        elif money > self.total:
            print(f"잔액이 부족합니다. 현재 총액: {self.total}원")
        else:
            print("0원 이하의 금액은 인출할 수 없습니다.")

    def get_total(self):
        return self.total


if __name__ == "__main__":
    box = Moneybox()
    box.deposit(10000)
    box.deposit(5000)
    box.extract(3000)
    print("현재 총액:", box.get_total(), "원")
# Out:
# 10000원을 입금했습니다. 총액: 10000원
# 5000원을 입금했습니다. 총액: 15000원
# 3000원을 인출했습니다. 총액: 12000원
# 현재 총액: 12000 원

# %% [markdown]
# my_money = Moneybox() 객체를 생성하고 1000원을 저축하고, 200원을 인출한다음, 총액을 출력하라.

# %%
class Moneybox:
    def __init__(self):
        self.total = 0

    def deposit(self, money):
        if money > 0:
            self.total += money
            print(f"{money}원을 입금했습니다. 총액: {self.total}원")
        else:
            print("0원 이하의 금액은 입금할 수 없습니다.")

    def extract(self, money):
        if money > 0 and money <= self.total:
            self.total -= money
            print(f"{money}원을 인출했습니다. 총액: {self.total}원")
        elif money > self.total:
            print(f"잔액이 부족합니다. 현재 총액: {self.total}원")
        else:
            print("0원 이하의 금액은 인출할 수 없습니다.")

    def get_total(self):
        return self.total


my_money = Moneybox()  
my_money.deposit(1000) 
my_money.extract(200) 
print("최종 총액:", my_money.get_total(), "원")
# Out:
# 1000원을 입금했습니다. 총액: 1000원
# 200원을 인출했습니다. 총액: 800원
# 최종 총액: 800 원
