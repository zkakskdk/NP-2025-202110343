# %% [markdown]
# Articles 클래스를 작성하라. 이 클래스는 각각 제품의 이름, 재고수량, 단가를 나타내는 name, stock, price 인스턴스 변수를 가지고 있다. offer_price() 메소드는 구매 수량을
# 인수로 전달받아 총가격을 반환한다. 구매수량이 1~10개이하이면 정상가격을 반환하고, 11~50개이면 5% 할인된 가격을 반환한다. 또 51개이상이면 10% 할인해준다. purchase() 메소드는
# 구매수량을 인수로 전달받아 재고수량을 구매수량만큼 감소한다

# %%
class Articles:
    def __init__(self, name, stock, price):
        self.name = name  
        self.stock = stock 
        self.price = price

    def offer_price(self, quantity):
        if quantity <= 0:
            print("구매 수량은 1개 이상이어야 합니다.")
            return 0

        total = self.price * quantity

        if 1 <= quantity <= 10:
            discount = 0
        elif 11 <= quantity <= 50:
            discount = 0.05
        else:  
            discount = 0.10

        final_price = total * (1 - discount)
        return final_price

    def purchase(self, quantity):
        if quantity <= 0:
            print("구매 수량은 1개 이상이어야 합니다.")
            return False
        if quantity > self.stock:
            print(f"재고가 부족합니다. 현재 재고: {self.stock}")
            return False

        self.stock -= quantity
        print(f"{quantity}개 구매 완료! 남은 재고: {self.stock}")
        return True


if __name__ == "__main__":
    article = Articles("USB 메모리", 100, 5000)

    print("5개 구매 가격:", article.offer_price(5)) 
    print("20개 구매 가격:", article.offer_price(20)) 
    print("60개 구매 가격:", article.offer_price(60))

    article.purchase(5)
    article.purchase(20)
    article.purchase(200)
# Out:
# 5개 구매 가격: 25000
# 20개 구매 가격: 95000.0
# 60개 구매 가격: 270000.0
# 5개 구매 완료! 남은 재고: 95
# 20개 구매 완료! 남은 재고: 75
# 재고가 부족합니다. 현재 재고: 75

# %% [markdown]
# 이 클래스를 이용하여 단가 1000원인 ”mask“를 10,000장으로 설정하고, 40장구매가격과 구매 후 재고를 출력하라.

# %%
class Articles:
    def __init__(self, name, stock, price):
        self.name = name  
        self.stock = stock  
        self.price = price 

    def offer_price(self, quantity):
        if quantity <= 0:
            print("구매 수량은 1개 이상이어야 합니다.")
            return 0

        total = self.price * quantity

        if 1 <= quantity <= 10:
            discount = 0
        elif 11 <= quantity <= 50:
            discount = 0.05
        else:  
            discount = 0.10

        final_price = total * (1 - discount)
        return final_price

    def purchase(self, quantity):
        if quantity <= 0:
            print("구매 수량은 1개 이상이어야 합니다.")
            return False
        if quantity > self.stock:
            print(f"재고가 부족합니다. 현재 재고: {self.stock}")
            return False

        self.stock -= quantity
        return True


if __name__ == "__main__":
    mask = Articles("mask", 10000, 1000)

    price = mask.offer_price(40)
    print("40장 구매 가격:", price, "원")

    mask.purchase(40)
    print("구매 후 남은 재고:", mask.stock, "장")
# Out:
# 40장 구매 가격: 38000.0 원
# 구매 후 남은 재고: 9960 장
